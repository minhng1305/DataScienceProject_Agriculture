# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import seaborn as sns
from ipywidgets import interact

# %%
# %matplotlib inline

# %%
data = pd.read_csv('/Users/mac/Desktop/Hello/Agriculture_Project/Agriculture_dataset.csv')
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
#Check if there is null value in dataset
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
data['label'].value_counts()
# Out:
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: label, dtype: int64

# %%
print('Average ratio of Nitrogen in the soil: {0:.2f}'.format(data['N'].mean()))
print('Average ratio of Phosphorous in the soil: {0:.2f}'.format(data['P'].mean()))
print('Average ratio of Potassium in the soil: {0:.2f}'.format(data['K'].mean()))
print('Average temperature in Celsius: {0:.2f}'.format(data['temperature'].mean()))
print('Average relative humidity in %: {0:.2f}'.format(data['humidity'].mean()))
print('Average PH value of the soil: {0:.2f}'.format(data['ph'].mean()))
print('Average rainfall in mm: {0:.2f}'.format(data['rainfall'].mean()))
# Out:
# Average ratio of Nitrogen in the soil: 50.55
# Average ratio of Phosphorous in the soil: 53.36
# Average ratio of Potassium in the soil: 48.15
# Average temperature in Celsius: 25.62
# Average relative humidity in %: 71.48
# Average PH value of the soil: 6.47
# Average rainfall in mm: 103.46

# %%
#Check statistic for each crop
@interact
def stat1(Crop = list(data['label'].value_counts().index)):
    x = data[data['label'] == Crop]
    print('Maximum Nitrogen required:', x['N'].max())
    print('Minimum Nitrogen required:', x['N'].min())
    print('Average Nitrogen required:', x['N'].mean())
    print("-------------------------")
    print('Maximum Phosphorous required:', x['P'].max())
    print('Minimum Phosphorous required:', x['P'].min())
    print('Average Phosphorous required:', x['P'].mean())
    print("-------------------------")
    print('Maximum Potassium required:', x['K'].max())
    print('Minimum Potassium required:', x['K'].min())
    print('Average Potassium required:', x['K'].mean())
    print("-------------------------")
    print('Maximum temperature required: {0:.2f}'.format(x['temperature'].max()))
    print('Minimum temperature required: {0:.2f}'.format(x['temperature'].min()))
    print('Average temperature required: {0:.2f}'.format(x['temperature'].mean()))
    print("-------------------------")
    print('Maximum PH required: {0:.2f}'.format(x['ph'].max()))
    print('Minimum PH required: {0:.2f}'.format(x['ph'].min()))
    print('Average PH required: {0:.2f}'.format(x['ph'].mean()))
    print("-------------------------")
    print('Maximum humidity required: {0:.2f}'.format(x['humidity'].max()))
    print('Minimum humidity required: {0:.2f}'.format(x['humidity'].min()))
    print('Average humidity required: {0:.2f}'.format(x['humidity'].mean()))
    print("-------------------------")
    print('Maximum rainfall required: {0:.2f}'.format(x['rainfall'].max()))
    print('Minimum rainfall required: {0:.2f}'.format(x['rainfall'].min()))
    print('Average rainfall required: {0:.2f}'.format(x['rainfall'].mean()))
# Out:
# interactive(children=(Dropdown(description='Crop', options=('rice', 'maize', 'jute', 'cotton', 'coconut', 'pap…

# %%
#Compare the average requirement for each crop
@interact
def stat2(Condition = ['N','P','K','temperature','humidity','ph','rainfall']):
    print("Average value for", Condition,"is {0:.2f}".format(data[Condition].mean()))
    print("Rice: {0:.2f}".format(data[data['label']=='rice'][Condition].mean()))
    print("Maize: {0:.2f}".format(data[data['label']=='maize'][Condition].mean()))
    print("Jute: {0:.2f}".format(data[data['label']=='jute'][Condition].mean()))
    print("Cotton: {0:.2f}".format(data[data['label']=='cotton'][Condition].mean()))
    print("Coconut: {0:.2f}".format(data[data['label']=='coconut'][Condition].mean()))
    print("Papaya: {0:.2f}".format(data[data['label']=='papaya'][Condition].mean()))
    print("Orange: {0:.2f}".format(data[data['label']=='orange'][Condition].mean()))
    print("Apple: {0:.2f}".format(data[data['label']=='apple'][Condition].mean()))
    print("Muskmelon: {0:.2f}".format(data[data['label']=='muskmelon'][Condition].mean()))
    print("Watermelon: {0:.2f}".format(data[data['label']=='watermelon'][Condition].mean()))
    print("Grapes: {0:.2f}".format(data[data['label']=='grapes'][Condition].mean()))
    print("Mango: {0:.2f}".format(data[data['label']=='mango'][Condition].mean()))
    print("Banana: {0:.2f}".format(data[data['label']=='banana'][Condition].mean()))
    print("Pomegranate: {0:.2f}".format(data[data['label']=='pomegranate'][Condition].mean()))
    print("Lentil: {0:.2f}".format(data[data['label']=='lentil'][Condition].mean()))
    print("Blackgram: {0:.2f}".format(data[data['label']=='blackgram'][Condition].mean()))
    print("Mungbean: {0:.2f}".format(data[data['label']=='mungbean'][Condition].mean()))
    print("Mothbeans: {0:.2f}".format(data[data['label']=='mothbeans'][Condition].mean()))
    print("Pigeonpeas: {0:.2f}".format(data[data['label']=='pigeonpeas'][Condition].mean()))
    print("Kidneybeans: {0:.2f}".format(data[data['label']=='kidneybeans'][Condition].mean()))
    print("Chickpea: {0:.2f}".format(data[data['label']=='chickpea'][Condition].mean()))
    print("Coffee: {0:.2f}".format(data[data['label']=='coffee'][Condition].mean()))
# Out:
# interactive(children=(Dropdown(description='Condition', options=('N', 'P', 'K', 'temperature', 'humidity', 'ph…

# %%
@interact
def comparison(Condition = ['N','P','K','temperature','humidity','ph','rainfall']):
    print("Crops requring greater than average",Condition,'\n')
    print(data[data[Condition] > data[Condition].mean()]['label'].unique(),'\n')
    print("Crops requring less than average",Condition,'\n')
    print(data[data[Condition] <= data[Condition].mean()]['label'].unique(),'\n')
# Out:
# interactive(children=(Dropdown(description='Condition', options=('N', 'P', 'K', 'temperature', 'humidity', 'ph…

# %% [markdown]
# # Distribution

# %%
#Check the distribution of Conditions
plt.rcParams['figure.figsize'] = (15, 7)

plt.subplot(3, 4, 1)
sns.distplot(data['N'])
plt.xlabel('Ratio of Nitrogen', fontsize = 12)
plt.grid()

plt.subplot(3, 4, 2)
sns.distplot (data['P'])
plt.xlabel('Ratio of Phosphorous', fontsize = 12)
plt.grid()

plt.subplot(3, 4, 3)
sns.distplot(data['K'])
plt.xlabel('Ratio of Potassium', fontsize = 12)
plt.grid()

plt.subplot(3,4,4)
sns.distplot(data['temperature'])
plt.xlabel('Temparature', fontsize = 12)
plt.grid()

plt.subplot(3,4,5)
sns.distplot(data['humidity'])
plt.xlabel('Humidity', fontsize = 12)
plt.grid()

plt.subplot(3,4,6)
sns.distplot(data['ph'])
plt.xlabel('PH', fontsize = 12)
plt.grid()

plt.subplot(3,4,7)
sns.distplot(data['rainfall'])
plt.xlabel('Rainfalls', fontsize = 12)
plt.grid()

plt.tight_layout()
# Out:
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#Observation
print('Crop requiring high Nitrogen ratio in soil:', data[data['N'] > 120]['label'].unique())
print('Crop requiring high Phosphorous ratio in soil:', data[data['P'] > 100]['label'].unique())
print('Crop requiring high Potassium ratio in soil:', data[data['K'] > 200]['label'].unique())
print('Crop requiring high rainfall:', data[data['rainfall'] > 200]['label'].unique())
print('Crop requiring high temperature:', data[data['temperature'] > 40]['label'].unique())
print('Crop requiring low temperature:', data[data['temperature'] < 10]['label'].unique())
print('Crop requiring low humidity:', data[data['humidity'] < 20]['label'].unique())
print('Crop requiring high PH:', data[data['ph'] > 9]['label'].unique())
print('Crop requiring low PH:', data[data['ph'] < 4]['label'].unique())
# Out:
# Crop requiring high Nitrogen ratio in soil: ['cotton']
# Crop requiring high Phosphorous ratio in soil: ['grapes' 'apple']
# Crop requiring high Potassium ratio in soil: ['grapes' 'apple']
# Crop requiring high rainfall: ['rice' 'papaya' 'coconut']
# Crop requiring high temperature: ['grapes' 'papaya']
# Crop requiring low temperature: ['grapes']
# Crop requiring low humidity: ['chickpea' 'kidneybeans']
# Crop requiring high PH: ['mothbeans']
# Crop requiring low PH: ['mothbeans']

# %%
#Conclude which crops are good for different seasons
print("Summer:")
print(data[(data['temperature'] > 30) & (data['humidity']>50)]['label'].unique())
print("\n")
print("Winter:")
print(data[(data['temperature'] < 20) & (data['humidity']>30)]['label'].unique())
print("\n")
print("Rainy season:")
print(data[(data['rainfall'] > 200) & (data['humidity']>30)]['label'].unique())
print("\n")
# Out:
# Summer:
# ['pigeonpeas' 'mothbeans' 'blackgram' 'mango' 'grapes' 'orange' 'papaya']
#
#
# Winter:
# ['maize' 'pigeonpeas' 'lentil' 'pomegranate' 'grapes' 'orange']
#
#
# Rainy season:
# ['rice' 'papaya' 'coconut']

# %% [markdown]
# # Clustering

# %%
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')

#Remove label columns
x = data.loc[:, ['N','P','K','temperature','humidity','ph','rainfall']].values

print(x.shape)

x_data = pd.DataFrame(x)
x_data.head()
# Out:
# (2200, 7)
#       0     1     2          3          4         5           6
# 0  90.0  42.0  43.0  20.879744  82.002744  6.502985  202.935536
# 1  85.0  58.0  41.0  21.770462  80.319644  7.038096  226.655537
# 2  60.0  55.0  44.0  23.004459  82.320763  7.840207  263.964248
# 3  74.0  35.0  40.0  26.491096  80.158363  6.980401  242.864034
# 4  78.0  42.0  42.0  20.130175  81.604873  7.628473  262.717340

# %%
#Optimum number of clusters
plt.rcParams['figure.figsize'] = (10, 4)
wcss = []
for i in range(1,11):
    km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init= 10, random_state = 0)
    km.fit(x)
    wcss.append(km.inertia_)

#Plot the result
plt.plot(range(1,11), wcss)
plt.title('Elbow Method', fontsize = 15)
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.show()

# %%
km = KMeans(n_clusters = 4, init = 'k-means++', max_iter = 300, n_init= 10, random_state = 0)
y_means = km.fit_predict(x)

#Result
a = data['label']
y_means = pd.DataFrame(y_means)
z = pd.concat([y_means, a], axis=1)
z = z.rename(columns = {0:'cluster'})

print("Crops in the 1st cluster:",z[z['cluster']==0]['label'].unique())
print("Crops in the 2nd cluster:",z[z['cluster']==1]['label'].unique())
print("Crops in the 3rd cluster:",z[z['cluster']==2]['label'].unique())
print("Crops in the 4th cluster:",z[z['cluster']==3]['label'].unique())
# Out:
# Crops in the 1st cluster: ['maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans' 'mungbean'
#  'blackgram' 'lentil' 'pomegranate' 'mango' 'orange' 'papaya' 'coconut']
# Crops in the 2nd cluster: ['maize' 'banana' 'watermelon' 'muskmelon' 'papaya' 'cotton' 'coffee']
# Crops in the 3rd cluster: ['grapes' 'apple']
# Crops in the 4th cluster: ['rice' 'pigeonpeas' 'papaya' 'coconut' 'jute' 'coffee']

# %% [markdown]
# # Predictive Modeling

# %%
#Split dataset
y = data['label']
x = data.drop(['label'], axis = 1)
print("Shape of x:", x.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of x: (2200, 7)
# Shape of y: (2200,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state = 0)
print("Shape of x train", x_train.shape)
print("Shape of x test", x_test.shape)
print("Shape of y train", y_train.shape)
print("Shape of y test", y_test.shape)
# Out:
# Shape of x train (1760, 7)
# Shape of x test (440, 7)
# Shape of y train (1760,)
# Shape of y test (440,)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
y_prediction = model.predict(x_test)

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test, y_prediction)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        18
#       banana       1.00      1.00      1.00        18
#    blackgram       0.86      0.82      0.84        22
#     chickpea       1.00      1.00      1.00        23
#      coconut       1.00      1.00      1.00        15
#       coffee       1.00      1.00      1.00        17
#       cotton       0.89      1.00      0.94        16
#       grapes       1.00      1.00      1.00        18
#         jute       0.84      1.00      0.91        21
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.94      0.94      0.94        17
#        maize       0.94      0.89      0.91        18
#        mango       1.00      1.00      1.00        21
#    mothbeans       0.88      0.92      0.90        25
#     mungbean       1.00      1.00      1.00        17
#    muskmelon       1.00      1.00      1.00        23
# ...
